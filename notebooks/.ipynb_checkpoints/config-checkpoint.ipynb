# %%
import sys
import numpy as np

sys.path.append("../scripts/config/")
import config

# %% [markdown]
# ### Actuator Trade Study

# %%
act_count = [1000, 1250, 1500, 1750, 2000, 2250, 2500, 2750, 3000, 3250, 3500, 3750, 4000, 4250, 4500, 4750, 5000, 5250, 5500, 5750, 6000]

# %%
sides, actuators = config.calc_actuator_separation(act_count)
# Out:
# --------------------
# Distance between actuators relative to primary mirror (m), dm.dx:
# --------------------
#        1000       0.308
#        1250       0.276
#        1500       0.252
#        1750       0.233
#        2000       0.218
#        2250       0.206
#        2500       0.195
#        2750       0.186
#        3000       0.178
#        3250       0.171
#        3500       0.165
#        3750       0.159
#        4000       0.154
#        4250       0.150
#        4500       0.145
#        4750       0.141
#        5000       0.138
#        5250       0.135
#        5500       0.131
#        5750       0.129
#        6000       0.126

# %%
import importlib
importlib.reload(config)
# Out:
# <module 'config' from '/System/Volumes/Data/mnt/g2/scratch/bpeck/ao/mcao/vismcao/notebooks/../scripts/config/config.py'>

# %%
params = config.calc_act_flux_params(act_count, lgs_mag=8, tt_mag=8)
# Out:
# --------------------
# VisMCAO Magnitude-to-Flux Parameters:
# --------------------
#
# ####
# #8mag LGS (8mag TT)
# ####
# #Actuator Count: 1000
# #dm.dx = [ 0.308 .168 .168 ]
# #powfs.siglev = [ 131.342 42387.592 41.558 ]
# #powfs.bkgrnd = [ 0.1 1.056 0.001 ]
# #powfs.nearecon = [ 133.982 0.269 202.516 ]
#
# ####
# #8mag LGS (8mag TT)
# ####
# #Actuator Count: 1250
# #dm.dx = [ 0.276 .168 .168 ]
# #powfs.siglev = [ 105.468 42387.592 41.558 ]
# #powfs.bkgrnd = [ 0.1 1.056 0.001 ]
# #powfs.nearecon = [ 150.347 0.269 202.516 ]
#
# ####
# #8mag LGS (8mag TT)
# ####
# #Actuator Count: 1500
# #dm.dx = [ 0.252 .168 .168 ]
# #powfs.siglev = [ 87.923 42387.592 41.558 ]
# #powfs.bkgrnd = [ 0.1 1.056 0.001 ]
# #powfs.nearecon = [ 165.582 0.269 202.516 ]
#
# ####
# #8mag LGS (8mag TT)
# ####
# #Actuator Count: 1750
# #dm.dx = [ 0.233 .168 .168 ]
# #powfs.siglev = [ 75.165 42387.592 41.558 ]
# #powfs.bkgrnd = [ 0.1 1.056 0.001 ]
# #powfs.nearecon = [ 180.09 0.269 202.516 ]
#
# ####
# ...
