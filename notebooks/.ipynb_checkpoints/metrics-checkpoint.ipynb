# %%
# IMPORT NECESSARY PACKAGES
import os
import sys
import numpy as np
import matplotlib.pyplot as plt

# PAARTI
from paarti.utils import maos_utils

# VISMCAO
sys.path.append("../scripts/plotting")
import utils

# %%
act_study = "../studies/act_count/10_lgs/8mag_lgs/"

# %%
actuator_count = np.arange(1000, 5776, 250)
seed=1
wfe = np.zeros((3, len(actuator_count)))

# %%
for i, act_count in enumerate(actuator_count):
    directory_path = os.path.join(act_study, f"{act_count}_actuators/")
    
    if act_count % 1000 == 0:
            print("Entering directory: ", act_count)

    wfe_metrics_kola = utils.get_wfe_metrics_over_field(directory=directory_path, seed=seed)
        
    _, clos_mean_nm, *_ = wfe_metrics_kola
           
    wfe[0, i] = clos_mean_nm[0]
    wfe[1, i] = clos_mean_nm[1]
    wfe[2, i] = clos_mean_nm[2]
# Out:
# Entering directory:  1000
# Looking in directory: ../studies/act_count/10_lgs/8mag_lgs/1000_actuators/
# Looking in directory: ../studies/act_count/10_lgs/8mag_lgs/1250_actuators/
# Looking in directory: ../studies/act_count/10_lgs/8mag_lgs/1500_actuators/
# Looking in directory: ../studies/act_count/10_lgs/8mag_lgs/1750_actuators/
# Entering directory:  2000
# Looking in directory: ../studies/act_count/10_lgs/8mag_lgs/2000_actuators/
# Looking in directory: ../studies/act_count/10_lgs/8mag_lgs/2250_actuators/
# Looking in directory: ../studies/act_count/10_lgs/8mag_lgs/2500_actuators/
# Looking in directory: ../studies/act_count/10_lgs/8mag_lgs/2750_actuators/
# Entering directory:  3000
# Looking in directory: ../studies/act_count/10_lgs/8mag_lgs/3000_actuators/
# Looking in directory: ../studies/act_count/10_lgs/8mag_lgs/3250_actuators/
# Looking in directory: ../studies/act_count/10_lgs/8mag_lgs/3500_actuators/
# Looking in directory: ../studies/act_count/10_lgs/8mag_lgs/3750_actuators/
# Entering directory:  4000
# Looking in directory: ../studies/act_count/10_lgs/8mag_lgs/4000_actuators/
# Looking in directory: ../studies/act_count/10_lgs/8mag_lgs/4250_actuators/
# Looking in directory: ../studies/act_count/10_lgs/8mag_lgs/4500_actuators/
# Looking in directory: ../studies/act_count/10_lgs/8mag_lgs/4750_actuators/
# Entering directory:  5000
# Looking in directory: ../studies/act_count/10_lgs/8mag_lgs/5000_actuators/
# Looking in directory: ../studies/act_count/10_lgs/8mag_lgs/5250_actuators/
# Looking in directory: ../studies/act_count/10_lgs/8mag_lgs/5500_actuators/
# Looking in directory: ../studies/act_count/10_lgs/8mag_lgs/5750_actuators/

# %%
wfe_colors = ["r", "g", "b"]
wfe_labels = ["Total WFE", "Tip-Tilt", "High-Order"]

for i in range(3):
    plt.plot(actuator_count, wfe[i], label=wfe_labels[i], color=wfe_colors[i])

plt.title('Wavefront Error vs. Actuator Count (10 LGS @8mag @30" radius)')
plt.xlabel("Actuator Count (n)")
plt.ylabel("Wavefront Error (nm)")
plt.legend()

# %%
for i, act_count in enumerate(actuator_count):
    directory_path = os.path.join(act_study, f"{act_count}_actuators/")
    
    if act_count % 1000 == 0:
            print("Entering directory: ", act_count)

    wfe_metrics_kola = utils.get_wfe_metrics_over_field(directory=directory_path, seed=seed)
        
    _, clos_mean_nm, *_ = wfe_metrics_kola
           
    wfe[0, i] = clos_mean_nm[0]
    wfe[1, i] = clos_mean_nm[1]
    wfe[2, i] = clos_mean_nm[2]
