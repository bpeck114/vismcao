# %%
from paarti.utils import maos_utils

# %%
maos_utils.print_wfe_metrics(seed=1)
# Out:
# ---------------------
# WaveFront Error (nm): [note, piston removed from all]
# ---------------------
# Field Avg        Total   High_Order           TT
# ---------  -----------   ----------   ----------
# Open             884.5        837.1        285.7
# Closed           365.1        354.5         87.4
#
# Pos  0
# -------
# Open             946.3        860.1        394.5
# Closed           133.1        119.4         58.9
#
# Pos  1
# -------
# Open             932.3        856.5        368.2
# Closed           144.3        130.3         62.2
#
# Pos  2
# -------
# Open             914.1        848.3        340.6
# Closed           147.8        133.3         63.8
#
# Pos  3
# -------
# Open             896.1        840.2        311.6
# Closed           138.6        123.0         63.9
#
# Pos  4
# -------
# Open             879.6        833.3        281.8
# Closed           153.2        139.2         64.1
#
# Pos  5
# -------
# Open             865.9        828.4        252.1
# ...
